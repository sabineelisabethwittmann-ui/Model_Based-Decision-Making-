# %% [markdown]
# # Sugarscape Model — Mesa 2.2 (Teaching Version)
#
# This notebook demonstrates the classic **Sugarscape model** using the Mesa 2.x framework.
#
# It shows:
# - How to define agents and an environment (grid with sugar patches)
# - How to use the **RandomActivation** scheduler
# - How to visualize an agent-based model with **CanvasGrid** inside Jupyter
# - How to plot collected data after the simulation

# %% [markdown]
# > Before running, make sure you have Mesa 2.2 installed:
# > ```bash
# > pip install "mesa>=2.2,<3.0" matplotlib
# > ```

# %%
from mesa import Agent, Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
from mesa.time import RandomActivation
from mesa.visualization.modules import CanvasGrid
from mesa.visualization.ModularVisualization import ModularServer
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ## Step 1 — Define the Environment

# %%
class SugarPatch(Agent):
    """A patch of sugar that regenerates over time."""
    def __init__(self, unique_id, model, pos, max_sugar):
        super().__init__(unique_id, model)
        self.pos = pos
        self.max_sugar = max_sugar
        self.amount = max_sugar

    def step(self):
        if self.amount < self.max_sugar:
            self.amount += 1

# %% [markdown]
# ## Step 2 — Define the Agents

# %%
class SugarAgent(Agent):
    """An agent that moves toward sugar, eats it, and expends metabolism."""
    def __init__(self, unique_id, model, pos, vision, metabolism, sugar):
        super().__init__(unique_id, model)
        self.pos = pos
        self.vision = vision
        self.metabolism = metabolism
        self.sugar = sugar

    def move(self):
        """Move to the cell with the most sugar within vision range."""
        best_cell = self.pos
        max_sugar = -1
        for dx, dy in [(1,0), (-1,0), (0,1), (0,-1)]:
            for dist in range(1, self.vision + 1):
                x = self.pos[0] + dx * dist
                y = self.pos[1] + dy * dist
                if 0 <= x < self.model.grid.width and 0 <= y < self.model.grid.height:
                    sugar_here = 0
                    for obj in self.model.grid.get_cell_list_contents((x, y)):
                        if isinstance(obj, SugarPatch):
                            sugar_here = obj.amount
                    if sugar_here > max_sugar:
                        best_cell = (x, y)
                        max_sugar = sugar_here
        self.model.grid.move_agent(self, best_cell)

    def eat(self):
        cell_contents = self.model.grid.get_cell_list_contents([self.pos])
        for obj in cell_contents:
            if isinstance(obj, SugarPatch):
                self.sugar += obj.amount
                obj.amount = 0

    def step(self):
        self.move()
        self.eat()
        self.sugar -= self.metabolism
        if self.sugar <= 0:
            self.model.grid.remove_agent(self)
            self.model.schedule.remove(self)

# %% [markdown]
# ## Step 3 — Define the Model

# %%
class SugarscapeModel(Model):
    """Sugarscape model (Mesa 2.2)."""
    def __init__(self, width=20, height=20, N=50):
        self.num_agents = N
        self.grid = MultiGrid(width, height, torus=False)
        self.schedule = RandomActivation(self)

        # Create sugar patches
        for cell in self.grid.coord_iter():
            if len(cell) == 2:
                contents, (x, y) = cell
            else:
                contents, x, y = cell

            max_sugar = 1
            if (x - width/4)**2 + (y - height/4)**2 < 25 or (x - 3*width/4)**2 + (y - 3*height/4)**2 < 25:
                max_sugar = 4
            patch = SugarPatch((x, y), self, (x, y), max_sugar)
            self.grid.place_agent(patch, (x, y))
            self.schedule.add(patch)

            # Create agents
        for i in range(self.num_agents):
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            vision = random.randint(1, 6)
            metabolism = random.randint(1, 4)
            sugar = random.randint(5, 25)
            agent = SugarAgent(i, self, (x, y), vision, metabolism, sugar)
            self.grid.place_agent(agent, (x, y))
            self.schedule.add(agent)

        self.datacollector = DataCollector(
            agent_reporters={"Sugar": "sugar"}
        )

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

# %% [markdown]
# ## Step 4 — Visualization in Jupyter

# %%
def agent_portrayal(agent):
    if isinstance(agent, SugarPatch):
        color_intensity = int(255 * agent.amount / agent.max_sugar)
        color = f"#ffff{color_intensity:02x}"
        return {
            "Shape": "rect",
            "Filled": "true",
            "Layer": 0,
            "Color": color,
            "w": 1,
            "h": 1
        }
    elif isinstance(agent, SugarAgent):
        return {
            "Shape": "circle",
            "Color": "blue",
            "Filled": "true",
            "Layer": 1,
            "r": 0.5
        }

grid = CanvasGrid(agent_portrayal, 20, 20, 500, 500)
m = SugarscapeModel(width=20, height=20, N=50)
# Out:
# /Users/mhlees/Library/CloudStorage/GoogleDrive-m.h.lees@computationalscience.nl/My Drive/Teaching/2025/Model Based Decisions/Code/.venv/lib/python3.13/site-packages/mesa/agent.py:52: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   self.model.register_agent(self)
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 6) is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 9) is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 10) is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 11) is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 12) is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 13) is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 14) is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 15) is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 16) is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 17) is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 18) is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 19) is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 4) is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 6) is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 9) is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 10) is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 11) is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 12) is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 13) is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 14) is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 15) is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 16) is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 17) is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 18) is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 19) is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 3) is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 6) is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 9) is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 10) is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 11) is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 12) is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 13) is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 14) is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 15) is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 16) is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 17) is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 18) is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 19) is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 0) is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 1) is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 2) is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 3) is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 4) is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 5) is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 6) is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 7) is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 8) is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 9) is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 10) is being placed with
# place_agent() despite already having the position (3, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 11) is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 12) is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 13) is being placed with
# place_agent() despite already having the position (3, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 14) is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 15) is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 16) is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 17) is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 18) is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 19) is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 0) is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 1) is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 2) is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 3) is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 4) is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 5) is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 6) is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 7) is being placed with
# place_agent() despite already having the position (4, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 8) is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 9) is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 10) is being placed with
# place_agent() despite already having the position (4, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 11) is being placed with
# place_agent() despite already having the position (4, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 12) is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 13) is being placed with
# place_agent() despite already having the position (4, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 14) is being placed with
# place_agent() despite already having the position (4, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 15) is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 16) is being placed with
# place_agent() despite already having the position (4, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 17) is being placed with
# place_agent() despite already having the position (4, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 18) is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 19) is being placed with
# place_agent() despite already having the position (4, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 0) is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 1) is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 2) is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 3) is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 4) is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 5) is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 6) is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 7) is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 8) is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 9) is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 10) is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 11) is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 12) is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 13) is being placed with
# place_agent() despite already having the position (5, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 14) is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 15) is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 16) is being placed with
# place_agent() despite already having the position (5, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 17) is being placed with
# place_agent() despite already having the position (5, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 18) is being placed with
# place_agent() despite already having the position (5, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 19) is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 0) is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 1) is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 2) is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 3) is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 4) is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 5) is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 6) is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 7) is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 8) is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 9) is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 10) is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 11) is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 12) is being placed with
# place_agent() despite already having the position (6, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 13) is being placed with
# place_agent() despite already having the position (6, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 14) is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 15) is being placed with
# place_agent() despite already having the position (6, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 16) is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 17) is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 18) is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 19) is being placed with
# place_agent() despite already having the position (6, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (7, 0) is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (7, 1) is being placed with
# place_agent() despite already having the position (7, 1). In most
# ...
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (4, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (16, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (16, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (6, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (17, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (15, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (10, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (16, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (19, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (4, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (11, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (16, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (10, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (18, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (14, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (11, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (13, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (17, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (13, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (18, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (16, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (9, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (15, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (11, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, (x, y))

# %%
server = ModularServer(
    SugarscapeModel,
    [grid],
    "Sugarscape Model",
    {"width": 20, "height": 20, "N": 50}
)
server.port = 8521
server.launch()
# Out:
# Interface starting at http://127.0.0.1:8521
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 6) is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 9) is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 10) is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 11) is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 12) is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 13) is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 14) is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 15) is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 16) is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 17) is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 18) is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (0, 19) is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 4) is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 6) is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 9) is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 10) is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 11) is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 12) is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 13) is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 14) is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 15) is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 16) is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 17) is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 18) is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (1, 19) is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 3) is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 6) is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 9) is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 10) is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 11) is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 12) is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 13) is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 14) is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 15) is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 16) is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 17) is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 18) is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (2, 19) is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 0) is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 1) is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 2) is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 3) is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 4) is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 5) is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 6) is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 7) is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 8) is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 9) is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 10) is being placed with
# place_agent() despite already having the position (3, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 11) is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 12) is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 13) is being placed with
# place_agent() despite already having the position (3, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 14) is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 15) is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 16) is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 17) is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 18) is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (3, 19) is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 0) is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 1) is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 2) is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 3) is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 4) is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 5) is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 6) is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 7) is being placed with
# place_agent() despite already having the position (4, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 8) is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 9) is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 10) is being placed with
# place_agent() despite already having the position (4, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 11) is being placed with
# place_agent() despite already having the position (4, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 12) is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 13) is being placed with
# place_agent() despite already having the position (4, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 14) is being placed with
# place_agent() despite already having the position (4, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 15) is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 16) is being placed with
# place_agent() despite already having the position (4, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 17) is being placed with
# place_agent() despite already having the position (4, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 18) is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (4, 19) is being placed with
# place_agent() despite already having the position (4, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 0) is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 1) is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 2) is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 3) is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 4) is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 5) is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 6) is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 7) is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 8) is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 9) is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 10) is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 11) is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 12) is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 13) is being placed with
# place_agent() despite already having the position (5, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 14) is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 15) is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 16) is being placed with
# place_agent() despite already having the position (5, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 17) is being placed with
# place_agent() despite already having the position (5, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 18) is being placed with
# place_agent() despite already having the position (5, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (5, 19) is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 0) is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 1) is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 2) is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 3) is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 4) is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 5) is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 6) is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 7) is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 8) is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 9) is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 10) is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 11) is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 12) is being placed with
# place_agent() despite already having the position (6, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 13) is being placed with
# place_agent() despite already having the position (6, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 14) is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 15) is being placed with
# place_agent() despite already having the position (6, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 16) is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 17) is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 18) is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (6, 19) is being placed with
# place_agent() despite already having the position (6, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (7, 0) is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (7, 1) is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(patch, (x, y))
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:19: UserWarning: Agent (7, 2) is being placed with
# place_agent() despite already having the position (7, 2). In most
# ...
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (8, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (8, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (16, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (16, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (16, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (13, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (14, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (4, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (14, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (13, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (14, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (10, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (10, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (18, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (8, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (11, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (15, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (10, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (19, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (9, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (15, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# /var/folders/hw/86l889_j4zq_8nlt1zg5j6gc0000gn/T/ipykernel_31278/3111202984.py:30: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (10, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 3.62ms
# {"type":"get_step","step":1}
# {"type":"get_step","step":2}
# {"type":"get_step","step":3}
# {"type":"get_step","step":4}
# {"type":"get_step","step":5}
# {"type":"get_step","step":6}
# {"type":"get_step","step":7}
# {"type":"get_step","step":8}
# {"type":"get_step","step":9}
# {"type":"get_step","step":10}
# {"type":"get_step","step":11}
# {"type":"get_step","step":12}
# {"type":"get_step","step":13}
# {"type":"get_step","step":14}
# {"type":"get_step","step":15}
# {"type":"get_step","step":16}
# {"type":"get_step","step":17}
# {"type":"get_step","step":18}
# {"type":"get_step","step":19}
# {"type":"get_step","step":20}
# {"type":"get_step","step":21}
# {"type":"get_step","step":22}
# {"type":"get_step","step":23}
# {"type":"get_step","step":24}
# {"type":"get_step","step":25}
# {"type":"get_step","step":26}
# {"type":"get_step","step":27}
# {"type":"get_step","step":28}
# {"type":"get_step","step":29}
# {"type":"get_step","step":30}
# {"type":"get_step","step":31}
# {"type":"get_step","step":32}
# {"type":"get_step","step":33}
# {"type":"get_step","step":34}
# {"type":"get_step","step":35}
# {"type":"get_step","step":36}
# {"type":"get_step","step":37}
# {"type":"get_step","step":38}
# {"type":"get_step","step":39}
# {"type":"get_step","step":40}
# {"type":"get_step","step":41}
# {"type":"get_step","step":42}
# {"type":"get_step","step":43}
# {"type":"get_step","step":44}
# {"type":"get_step","step":45}
# {"type":"get_step","step":46}
# {"type":"get_step","step":47}
# {"type":"get_step","step":48}
# {"type":"get_step","step":49}
# {"type":"get_step","step":50}
# {"type":"get_step","step":51}
# {"type":"get_step","step":52}
# {"type":"get_step","step":53}
# {"type":"get_step","step":54}
# {"type":"get_step","step":55}
# {"type":"get_step","step":56}
# {"type":"get_step","step":57}
# {"type":"get_step","step":58}
# {"type":"get_step","step":59}
# {"type":"get_step","step":60}
# {"type":"get_step","step":61}
# {"type":"get_step","step":62}
# {"type":"get_step","step":63}
# {"type":"get_step","step":64}
# {"type":"get_step","step":65}
# {"type":"get_step","step":66}
# {"type":"get_step","step":67}
# {"type":"get_step","step":68}
# {"type":"get_step","step":69}
# {"type":"get_step","step":70}
# {"type":"get_step","step":71}
# {"type":"get_step","step":72}
# {"type":"get_step","step":73}
# {"type":"get_step","step":74}
# {"type":"get_step","step":75}
# {"type":"get_step","step":76}
# {"type":"get_step","step":77}
# {"type":"get_step","step":78}
# {"type":"get_step","step":79}
# {"type":"get_step","step":80}
# {"type":"get_step","step":81}
# {"type":"get_step","step":82}
# {"type":"get_step","step":83}
# {"type":"get_step","step":84}
# {"type":"get_step","step":85}
# {"type":"get_step","step":86}
# {"type":"get_step","step":87}
# {"type":"get_step","step":88}
# {"type":"get_step","step":89}
# {"type":"get_step","step":90}
# {"type":"get_step","step":91}
# {"type":"get_step","step":92}
# {"type":"get_step","step":93}
# {"type":"get_step","step":94}
# {"type":"get_step","step":95}
# {"type":"get_step","step":96}
# {"type":"get_step","step":97}
# {"type":"get_step","step":98}
# {"type":"get_step","step":99}
# {"type":"get_step","step":100}
# {"type":"get_step","step":101}
# {"type":"get_step","step":102}
# {"type":"get_step","step":103}
# {"type":"get_step","step":104}
# {"type":"get_step","step":105}
# {"type":"get_step","step":106}
# {"type":"get_step","step":107}
# {"type":"get_step","step":108}
# {"type":"get_step","step":109}
# {"type":"get_step","step":110}
# {"type":"get_step","step":111}
# {"type":"get_step","step":112}
# {"type":"get_step","step":113}
# {"type":"get_step","step":114}
# {"type":"get_step","step":115}
# {"type":"get_step","step":116}
# {"type":"get_step","step":117}
# {"type":"get_step","step":118}
# {"type":"get_step","step":119}
# {"type":"get_step","step":120}
# {"type":"get_step","step":121}
# {"type":"get_step","step":122}
# {"type":"get_step","step":123}
# {"type":"get_step","step":124}
# {"type":"get_step","step":125}
# {"type":"get_step","step":126}
# {"type":"get_step","step":127}
# {"type":"get_step","step":128}
# {"type":"get_step","step":129}
# {"type":"get_step","step":130}
# {"type":"get_step","step":131}
# {"type":"get_step","step":132}

# %% [markdown]
# ## Step 5 — Post-Simulation Analysis

# %%
# Run simulation (headless) for analysis
model = SugarscapeModel(width=20, height=20, N=60)
for i in range(50):
    model.step()

agent_data = model.datacollector.get_agent_vars_dataframe()
final_sugar = agent_data.xs(49, level="Step")["Sugar"]

plt.figure(figsize=(6,4))
plt.hist(final_sugar, bins=12, color="skyblue", edgecolor="black")
plt.xlabel("Sugar (Wealth)")
plt.ylabel("Number of Agents")
plt.title("Wealth Distribution after 50 Steps")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✅ Teaching Ideas
# - Have students vary parameters (`N`, `vision`, `metabolism`) and observe changes.
# - Introduce a second resource ("spice") and explore trade.
# - Compute the Gini coefficient to measure inequality.
